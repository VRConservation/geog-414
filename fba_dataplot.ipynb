# %% [markdown]
# ### Code to import FBA contact data and plot with seaborn
# Notebook is in the top level folder of the Geog-414 folder in downloads at
# 'C:/Users/vance/Downloads/geog-414'

# %%
# Already installed with gee venv 3.12.0
# %pip install seaborn

# %%
# import packages
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Load data and view df. (When I transferred this to onedrive it wouldn't read it)
# So left it in the downloads folder
fba = pd.read_csv('C:/Users/vance/Downloads/fba.csv')
fba
# Out:
#                   Name                          Organization         Type  \
# 0     Cherilyn Ashmead         United Auburn Indian Community      Tribal
# 1          Royal Ramey  Fire and Forestry Recruitment Program   Nonprofit
# 2       Masha Chernyak             Latin Community Foundation   Nonprofit
# 3         Danna Stroud                                  GoBiz  Government
# 4      Jill Drinkwater                                  GoBiz  Government
# ..                 ...                                    ...         ...
# 144       Belen Bernal                    Nature for All (LA)   Nonprofit
# 145         Mark Lever                         Shasta College   Nonprofit
# 146  Patricia Carrillo                                   ALBA   Nonprofit
# 147         Liz Aviles                 Kitchen Table Advisors   Nonprofit
# 148    Katherine Favor                             NCAT/ATTRA   Nonprofit
#
#              Pipeline   Lead Date_1st_Contacted Contacted_1_month  Contacted2  \
# ...

# %%
# Plot pipeline counts
fba.groupby('Pipeline').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# scatterplot timeline with legend in upper left

sns.scatterplot(data=fba, x='Date_1st_Contacted', y='Type', hue='Pipeline', palette='Dark2')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.show()
