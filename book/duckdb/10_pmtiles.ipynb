# %% [markdown]
# # Visualizing PMTiles
#
# [PMTiles](https://github.com/protomaps/PMTiles) is a single-file archive format for tiled data. A PMTiles archive can be hosted on a common storage platform such as S3, and enables low-cost, zero-maintenance map applications that are "serverless" - free of a custom tile backend or third party provider.

# %% [markdown]
# ## Installation
#
# Uncomment and run the following cell to install the dependencies.

# %%
# %pip install -U "leafmap[pmtiles]"
# Out:
# Collecting leafmap[pmtiles]
#   Obtaining dependency information for leafmap[pmtiles] from https://files.pythonhosted.org/packages/20/b2/f61e33dd661014cfd2de19fe813c96d4d030dd4ad4899c01c1f83c58ee46/leafmap-0.29.3-py2.py3-none-any.whl.metadata
#   Downloading leafmap-0.29.3-py2.py3-none-any.whl.metadata (17 kB)
# Collecting bqplot (from leafmap[pmtiles])
#   Obtaining dependency information for bqplot from https://files.pythonhosted.org/packages/90/2c/e448c4def923fe67dc21f5641f930c26cc0f649a5a5a19aedee8a6be6a91/bqplot-0.12.42-py2.py3-none-any.whl.metadata
#   Using cached bqplot-0.12.42-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting colour (from leafmap[pmtiles])
#   Using cached colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Collecting duckdb (from leafmap[pmtiles])
#   Obtaining dependency information for duckdb from https://files.pythonhosted.org/packages/de/a6/381e4d1758dcb58188557e9bfceafef55b791bd3c70c730b8906b7fb1072/duckdb-0.9.2-cp39-cp39-win_amd64.whl.metadata
#   Downloading duckdb-0.9.2-cp39-cp39-win_amd64.whl.metadata (798 bytes)
# Collecting folium (from leafmap[pmtiles])
#   Obtaining dependency information for folium from https://files.pythonhosted.org/packages/a2/1a/37c7ee1bc806d6c32621fecc72c19f6a9f9b4369e5e8f406a7c16d49f031/folium-0.15.0-py2.py3-none-any.whl.metadata
#   Using cached folium-0.15.0-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting gdown (from leafmap[pmtiles])
#   Using cached gdown-4.7.1-py3-none-any.whl (15 kB)
# Collecting geojson (from leafmap[pmtiles])
#   Obtaining dependency information for geojson from https://files.pythonhosted.org/packages/8e/1b/4f57660aa148d3e3043d048b7e1ab87dfeb85204d0fdb5b4e19c08202162/geojson-3.1.0-py3-none-any.whl.metadata
#   Using cached geojson-3.1.0-py3-none-any.whl.metadata (16 kB)
# Collecting ipyevents (from leafmap[pmtiles])
#   Obtaining dependency information for ipyevents from https://files.pythonhosted.org/packages/af/49/5692d363a82838282f5c33a787922f07115d7ba4b452391e51db95c9d247/ipyevents-2.0.2-py3-none-any.whl.metadata
#   Using cached ipyevents-2.0.2-py3-none-any.whl.metadata (2.9 kB)
# Collecting ipyfilechooser (from leafmap[pmtiles])
#   Using cached ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Collecting ipyleaflet (from leafmap[pmtiles])
#   Obtaining dependency information for ipyleaflet from https://files.pythonhosted.org/packages/04/b9/210c42543136022c409e6daa84181b330a6c42ff561eb2470132109333ed/ipyleaflet-0.18.0-py3-none-any.whl.metadata
#   Downloading ipyleaflet-0.18.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: ipywidgets in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from leafmap[pmtiles]) (8.0.4)
# Requirement already satisfied: matplotlib in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from leafmap[pmtiles]) (3.7.2)
# Requirement already satisfied: numpy in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from leafmap[pmtiles]) (1.24.3)
# Requirement already satisfied: pandas in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from leafmap[pmtiles]) (2.0.3)
# Requirement already satisfied: plotly in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from leafmap[pmtiles]) (5.9.0)
# Collecting pyshp (from leafmap[pmtiles])
#   Using cached pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
# Collecting pystac-client (from leafmap[pmtiles])
#   Obtaining dependency information for pystac-client from https://files.pythonhosted.org/packages/95/57/a9c987b9c9d6c41bbe7050ea5f1ac50c9e50af5c317e6e9122066aeef822/pystac_client-0.7.5-py3-none-any.whl.metadata
#   Using cached pystac_client-0.7.5-py3-none-any.whl.metadata (5.2 kB)
# Collecting python-box (from leafmap[pmtiles])
#   Obtaining dependency information for python-box from https://files.pythonhosted.org/packages/6b/bd/ed4960ef50f5e43ef04f9b068ee5b42cde56b2a97aeb2dbfd4ec68322d0d/python_box-7.1.1-cp39-cp39-win_amd64.whl.metadata
#   Downloading python_box-7.1.1-cp39-cp39-win_amd64.whl.metadata (8.0 kB)
# Collecting scooby (from leafmap[pmtiles])
#   Obtaining dependency information for scooby from https://files.pythonhosted.org/packages/df/7b/25af5b3327c23ec3053f54a50b120679baf319f5d67047203cf42a02b545/scooby-0.9.2-py3-none-any.whl.metadata
#   Using cached scooby-0.9.2-py3-none-any.whl.metadata (15 kB)
# Collecting whiteboxgui (from leafmap[pmtiles])
#   Using cached whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
# Requirement already satisfied: xyzservices in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from leafmap[pmtiles]) (2022.9.0)
# Collecting pmtiles (from leafmap[pmtiles])
#   Obtaining dependency information for pmtiles from https://files.pythonhosted.org/packages/63/33/4b4d91c89c8dcd2d2494eae3b8b56a36ff52b9e85840e380749e8d45a87a/pmtiles-3.2.0-py3-none-any.whl.metadata
#   Downloading pmtiles-3.2.0-py3-none-any.whl.metadata (495 bytes)
# Requirement already satisfied: flask in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from leafmap[pmtiles]) (2.2.2)
# Collecting flask-cors (from leafmap[pmtiles])
#   Obtaining dependency information for flask-cors from https://files.pythonhosted.org/packages/10/69/1e6cfb87117568a9de088c32d6258219e9d1ff7c131abf74249ef2031279/Flask_Cors-4.0.0-py2.py3-none-any.whl.metadata
#   Using cached Flask_Cors-4.0.0-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from bqplot->leafmap[pmtiles]) (5.7.1)
# Collecting traittypes>=0.0.6 (from bqplot->leafmap[pmtiles])
#   Using cached traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from ipywidgets->leafmap[pmtiles]) (6.25.0)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from ipywidgets->leafmap[pmtiles]) (8.15.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from ipywidgets->leafmap[pmtiles]) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from ipywidgets->leafmap[pmtiles]) (3.0.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vance\appdata\roaming\python\python39\site-packages (from pandas->leafmap[pmtiles]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from pandas->leafmap[pmtiles]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from pandas->leafmap[pmtiles]) (2023.3)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from flask->leafmap[pmtiles]) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from flask->leafmap[pmtiles]) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from flask->leafmap[pmtiles]) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from flask->leafmap[pmtiles]) (8.0.4)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from flask->leafmap[pmtiles]) (6.0.0)
# Collecting branca>=0.6.0 (from folium->leafmap[pmtiles])
#   Obtaining dependency information for branca>=0.6.0 from https://files.pythonhosted.org/packages/2f/e7/603b136221de923055716d23e3047da71f92e0d8ba2c4517ce49a54fe768/branca-0.7.0-py3-none-any.whl.metadata
#   Using cached branca-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: requests in c:\users\vance\appdata\roaming\python\python39\site-packages (from folium->leafmap[pmtiles]) (2.31.0)
# Requirement already satisfied: filelock in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from gdown->leafmap[pmtiles]) (3.9.0)
# Requirement already satisfied: six in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from gdown->leafmap[pmtiles]) (1.16.0)
# Requirement already satisfied: tqdm in c:\users\vance\appdata\roaming\python\python39\site-packages (from gdown->leafmap[pmtiles]) (4.65.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from gdown->leafmap[pmtiles]) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from matplotlib->leafmap[pmtiles]) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from matplotlib->leafmap[pmtiles]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from matplotlib->leafmap[pmtiles]) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from matplotlib->leafmap[pmtiles]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from matplotlib->leafmap[pmtiles]) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from matplotlib->leafmap[pmtiles]) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from matplotlib->leafmap[pmtiles]) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from matplotlib->leafmap[pmtiles]) (5.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\vance\appdata\roaming\python\python39\site-packages (from plotly->leafmap[pmtiles]) (8.2.2)
# Collecting pystac[validation]>=1.8.2 (from pystac-client->leafmap[pmtiles])
#   Obtaining dependency information for pystac[validation]>=1.8.2 from https://files.pythonhosted.org/packages/2a/34/190016e443ff35ed24efacc810b0ae5d770022e8d3fb460608c0764f6c6d/pystac-1.9.0-py3-none-any.whl.metadata
#   Using cached pystac-1.9.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting ipytree (from whiteboxgui->leafmap[pmtiles])
#   Using cached ipytree-0.2.2-py2.py3-none-any.whl (1.3 MB)
# Collecting whitebox (from whiteboxgui->leafmap[pmtiles])
#   Using cached whitebox-2.3.1-py2.py3-none-any.whl (72 kB)
# Requirement already satisfied: colorama in c:\users\vance\appdata\roaming\python\python39\site-packages (from click>=8.0->flask->leafmap[pmtiles]) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from importlib-metadata>=3.6.0->flask->leafmap[pmtiles]) (3.11.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[pmtiles]) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[pmtiles]) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[pmtiles]) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[pmtiles]) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[pmtiles]) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[pmtiles]) (1.5.6)
# Requirement already satisfied: psutil in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[pmtiles]) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[pmtiles]) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[pmtiles]) (6.3.2)
# Requirement already satisfied: backcall in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (0.2.0)
# Requirement already satisfied: decorator in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (0.2.0)
# Requirement already satisfied: typing-extensions in c:\users\vance\appdata\roaming\python\python39\site-packages (from ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (4.7.1)
# Requirement already satisfied: exceptiongroup in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (1.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from Jinja2>=3.0->flask->leafmap[pmtiles]) (2.1.1)
# Collecting jsonschema~=4.18 (from pystac[validation]>=1.8.2->pystac-client->leafmap[pmtiles])
#   Obtaining dependency information for jsonschema~=4.18 from https://files.pythonhosted.org/packages/0f/ed/0058234d8dd2b1fc6beeea8eab945191a05e9d391a63202f49fe23327586/jsonschema-4.20.0-py3-none-any.whl.metadata
#   Downloading jsonschema-4.20.0-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vance\appdata\roaming\python\python39\site-packages (from requests->folium->leafmap[pmtiles]) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from requests->folium->leafmap[pmtiles]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from requests->folium->leafmap[pmtiles]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from requests->folium->leafmap[pmtiles]) (2023.7.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from beautifulsoup4->gdown->leafmap[pmtiles]) (2.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from requests->folium->leafmap[pmtiles]) (1.7.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (0.8.3)
# Collecting attrs>=22.2.0 (from jsonschema~=4.18->pystac[validation]>=1.8.2->pystac-client->leafmap[pmtiles])
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema~=4.18->pystac[validation]>=1.8.2->pystac-client->leafmap[pmtiles])
#   Obtaining dependency information for jsonschema-specifications>=2023.03.6 from https://files.pythonhosted.org/packages/20/a9/384ec45013ab883d7c2bf120f2988682986fdead973decf0bae28a4523e7/jsonschema_specifications-2023.11.1-py3-none-any.whl.metadata
#   Downloading jsonschema_specifications-2023.11.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting referencing>=0.28.4 (from jsonschema~=4.18->pystac[validation]>=1.8.2->pystac-client->leafmap[pmtiles])
#   Obtaining dependency information for referencing>=0.28.4 from https://files.pythonhosted.org/packages/29/c1/69342fbc8efd1aac5cda853cea771763b95d92325c4f8f83b499c07bc698/referencing-0.31.0-py3-none-any.whl.metadata
#   Downloading referencing-0.31.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema~=4.18->pystac[validation]>=1.8.2->pystac-client->leafmap[pmtiles])
#   Obtaining dependency information for rpds-py>=0.7.1 from https://files.pythonhosted.org/packages/ee/09/5c1d251760037d4ce12440f40c145e785a2118bd82bb72c291a0f94fb782/rpds_py-0.13.1-cp39-none-win_amd64.whl.metadata
#   Downloading rpds_py-0.13.1-cp39-none-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: entrypoints in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->leafmap[pmtiles]) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->leafmap[pmtiles]) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->leafmap[pmtiles]) (305.1)
# Requirement already satisfied: wcwidth in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (0.2.5)
# Requirement already satisfied: executing in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->leafmap[pmtiles]) (0.2.2)
# Using cached bqplot-0.12.42-py2.py3-none-any.whl (1.2 MB)
# Downloading duckdb-0.9.2-cp39-cp39-win_amd64.whl (10.3 MB)
#    ---------------------------------------- 0.0/10.3 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.3 MB 3.2 MB/s eta 0:00:04
#     --------------------------------------- 0.2/10.3 MB 2.4 MB/s eta 0:00:05
#     --------------------------------------- 0.2/10.3 MB 2.0 MB/s eta 0:00:06
#    - -------------------------------------- 0.3/10.3 MB 1.8 MB/s eta 0:00:06
#    - -------------------------------------- 0.3/10.3 MB 1.8 MB/s eta 0:00:06
#    - -------------------------------------- 0.4/10.3 MB 1.7 MB/s eta 0:00:06
#    - -------------------------------------- 0.5/10.3 MB 1.7 MB/s eta 0:00:06
#    -- ------------------------------------- 0.6/10.3 MB 1.8 MB/s eta 0:00:06
#    -- ------------------------------------- 0.7/10.3 MB 1.9 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/10.3 MB 1.9 MB/s eta 0:00:05
#    --- ------------------------------------ 0.9/10.3 MB 1.9 MB/s eta 0:00:06
#    --- ------------------------------------ 0.9/10.3 MB 1.8 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/10.3 MB 1.7 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.1/10.3 MB 1.7 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.2/10.3 MB 1.8 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/10.3 MB 1.9 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.4/10.3 MB 1.9 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.5/10.3 MB 1.9 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/10.3 MB 1.9 MB/s eta 0:00:05
#    ------ --------------------------------- 1.7/10.3 MB 1.9 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/10.3 MB 1.9 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/10.3 MB 1.8 MB/s eta 0:00:05
#    ------- -------------------------------- 1.9/10.3 MB 1.8 MB/s eta 0:00:05
#    ------- -------------------------------- 2.0/10.3 MB 1.8 MB/s eta 0:00:05
#    -------- ------------------------------- 2.1/10.3 MB 1.9 MB/s eta 0:00:05
#    -------- ------------------------------- 2.2/10.3 MB 1.9 MB/s eta 0:00:05
#    --------- ------------------------------ 2.3/10.3 MB 1.9 MB/s eta 0:00:05
#    --------- ------------------------------ 2.5/10.3 MB 1.9 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.6/10.3 MB 2.0 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.7/10.3 MB 2.0 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.8/10.3 MB 2.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.9/10.3 MB 2.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.1/10.3 MB 2.0 MB/s eta 0:00:04
#    ------------ --------------------------- 3.1/10.3 MB 2.0 MB/s eta 0:00:04
#    ------------ --------------------------- 3.3/10.3 MB 2.1 MB/s eta 0:00:04
#    ------------ --------------------------- 3.3/10.3 MB 2.1 MB/s eta 0:00:04
#    ------------- -------------------------- 3.5/10.3 MB 2.1 MB/s eta 0:00:04
#    ------------- -------------------------- 3.6/10.3 MB 2.1 MB/s eta 0:00:04
#    -------------- ------------------------- 3.7/10.3 MB 2.1 MB/s eta 0:00:04
#    -------------- ------------------------- 3.8/10.3 MB 2.1 MB/s eta 0:00:04
#    --------------- ------------------------ 3.9/10.3 MB 2.1 MB/s eta 0:00:04
#    --------------- ------------------------ 4.0/10.3 MB 2.1 MB/s eta 0:00:04
#    --------------- ------------------------ 4.0/10.3 MB 2.1 MB/s eta 0:00:04
#    --------------- ------------------------ 4.1/10.3 MB 2.1 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.1/10.3 MB 2.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.2/10.3 MB 2.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.2/10.3 MB 2.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.3/10.3 MB 2.0 MB/s eta 0:00:04
#    ----------------- ---------------------- 4.4/10.3 MB 2.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.5/10.3 MB 2.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.6/10.3 MB 2.0 MB/s eta 0:00:03
#    ------------------ --------------------- 4.7/10.3 MB 2.0 MB/s eta 0:00:03
#    ------------------ --------------------- 4.8/10.3 MB 2.0 MB/s eta 0:00:03
#    ------------------- -------------------- 5.0/10.3 MB 2.0 MB/s eta 0:00:03
#    ------------------- -------------------- 5.1/10.3 MB 2.0 MB/s eta 0:00:03
#    -------------------- ------------------- 5.2/10.3 MB 2.1 MB/s eta 0:00:03
#    -------------------- ------------------- 5.3/10.3 MB 2.1 MB/s eta 0:00:03
#    --------------------- ------------------ 5.4/10.3 MB 2.1 MB/s eta 0:00:03
#    --------------------- ------------------ 5.6/10.3 MB 2.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.7/10.3 MB 2.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.8/10.3 MB 2.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.9/10.3 MB 2.1 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.0/10.3 MB 2.1 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.1/10.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------ --------------- 6.2/10.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------ --------------- 6.3/10.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------ --------------- 6.4/10.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------- -------------- 6.5/10.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------- -------------- 6.6/10.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------- -------------- 6.6/10.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------- -------------- 6.6/10.3 MB 2.1 MB/s eta 0:00:02
#    -------------------------- ------------- 6.7/10.3 MB 2.1 MB/s eta 0:00:02
#    -------------------------- ------------- 6.8/10.3 MB 2.1 MB/s eta 0:00:02
#    -------------------------- ------------- 7.0/10.3 MB 2.1 MB/s eta 0:00:02
#    --------------------------- ------------ 7.1/10.3 MB 2.1 MB/s eta 0:00:02
#    --------------------------- ------------ 7.2/10.3 MB 2.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.3/10.3 MB 2.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.4/10.3 MB 2.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.6/10.3 MB 2.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.7/10.3 MB 2.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.8/10.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------------ --------- 7.8/10.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------------ --------- 7.8/10.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------------ --------- 7.9/10.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------------ --------- 8.0/10.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 8.1/10.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 8.2/10.3 MB 2.1 MB/s eta 0:00:02
#    -------------------------------- ------- 8.3/10.3 MB 2.1 MB/s eta 0:00:01
#    -------------------------------- ------- 8.5/10.3 MB 2.1 MB/s eta 0:00:01
#    --------------------------------- ------ 8.6/10.3 MB 2.1 MB/s eta 0:00:01
#    --------------------------------- ------ 8.7/10.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.8/10.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.8/10.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.9/10.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.9/10.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.9/10.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.0/10.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.0/10.3 MB 2.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.1/10.3 MB 2.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.2/10.3 MB 2.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.3/10.3 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 9.4/10.3 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 9.5/10.3 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 9.6/10.3 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 9.7/10.3 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 9.9/10.3 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 10.0/10.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  10.1/10.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  10.2/10.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  10.3/10.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 10.3/10.3 MB 2.1 MB/s eta 0:00:00
# Using cached Flask_Cors-4.0.0-py2.py3-none-any.whl (14 kB)
# Using cached folium-0.15.0-py2.py3-none-any.whl (100 kB)
# Using cached geojson-3.1.0-py3-none-any.whl (15 kB)
# Using cached ipyevents-2.0.2-py3-none-any.whl (101 kB)
# Downloading ipyleaflet-0.18.0-py3-none-any.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    - -------------------------------------- 0.1/3.7 MB 2.2 MB/s eta 0:00:02
#    -- ------------------------------------- 0.2/3.7 MB 2.9 MB/s eta 0:00:02
#    --- ------------------------------------ 0.3/3.7 MB 2.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.5/3.7 MB 2.6 MB/s eta 0:00:02
#    ------ --------------------------------- 0.6/3.7 MB 2.6 MB/s eta 0:00:02
#    ------- -------------------------------- 0.7/3.7 MB 2.6 MB/s eta 0:00:02
#    -------- ------------------------------- 0.8/3.7 MB 2.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.9/3.7 MB 2.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.1/3.7 MB 2.6 MB/s eta 0:00:02
#    ------------ --------------------------- 1.2/3.7 MB 2.5 MB/s eta 0:00:01
#    ------------- -------------------------- 1.3/3.7 MB 2.6 MB/s eta 0:00:01
#    --------------- ------------------------ 1.4/3.7 MB 2.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.5/3.7 MB 2.6 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.6/3.7 MB 2.6 MB/s eta 0:00:01
#    ------------------ --------------------- 1.7/3.7 MB 2.5 MB/s eta 0:00:01
#    ------------------- -------------------- 1.8/3.7 MB 2.6 MB/s eta 0:00:01
#    -------------------- ------------------- 1.9/3.7 MB 2.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.0/3.7 MB 2.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.2/3.7 MB 2.6 MB/s eta 0:00:01
#    ------------------------ --------------- 2.3/3.7 MB 2.6 MB/s eta 0:00:01
#    ------------------------- -------------- 2.4/3.7 MB 2.6 MB/s eta 0:00:01
#    --------------------------- ------------ 2.5/3.7 MB 2.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.6/3.7 MB 2.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.7/3.7 MB 2.6 MB/s eta 0:00:01
#    ------------------------------- -------- 2.9/3.7 MB 2.6 MB/s eta 0:00:01
#    -------------------------------- ------- 3.0/3.7 MB 2.6 MB/s eta 0:00:01
#    --------------------------------- ------ 3.1/3.7 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.2/3.7 MB 2.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.3/3.7 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------ --- 3.3/3.7 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 3.4/3.7 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 3.4/3.7 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 3.5/3.7 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 3.6/3.7 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  3.6/3.7 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  3.6/3.7 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  3.7/3.7 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 2.2 MB/s eta 0:00:00
# Downloading leafmap-0.29.3-py2.py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.8 MB 1.3 MB/s eta 0:00:02
#    - -------------------------------------- 0.1/1.8 MB 812.7 kB/s eta 0:00:03
#    -- ------------------------------------- 0.1/1.8 MB 819.2 kB/s eta 0:00:03
#    --- ------------------------------------ 0.1/1.8 MB 847.9 kB/s eta 0:00:02
#    --- ------------------------------------ 0.2/1.8 MB 817.0 kB/s eta 0:00:03
#    --- ------------------------------------ 0.2/1.8 MB 817.0 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.2/1.8 MB 758.5 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.2/1.8 MB 752.5 kB/s eta 0:00:03
#    ------ --------------------------------- 0.3/1.8 MB 707.1 kB/s eta 0:00:03
#    ------- -------------------------------- 0.3/1.8 MB 724.7 kB/s eta 0:00:03
#    -------- ------------------------------- 0.4/1.8 MB 802.3 kB/s eta 0:00:02
#    ---------- ----------------------------- 0.5/1.8 MB 932.7 kB/s eta 0:00:02
#    ------------- -------------------------- 0.6/1.8 MB 1.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 0.7/1.8 MB 1.2 MB/s eta 0:00:01
#    ------------------ --------------------- 0.8/1.8 MB 1.2 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/1.8 MB 1.4 MB/s eta 0:00:01
#    ------------------------ --------------- 1.1/1.8 MB 1.4 MB/s eta 0:00:01
#    -------------------------- ------------- 1.2/1.8 MB 1.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.3/1.8 MB 1.6 MB/s eta 0:00:01
#    ------------------------------- -------- 1.4/1.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.8 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 1.7/1.8 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 1.7 MB/s eta 0:00:00
# Downloading pmtiles-3.2.0-py3-none-any.whl (13 kB)
# Using cached pystac_client-0.7.5-py3-none-any.whl (33 kB)
# Using cached python_box-7.1.1-cp39-cp39-win_amd64.whl (1.2 MB)
# Using cached scooby-0.9.2-py3-none-any.whl (18 kB)
# Using cached branca-0.7.0-py3-none-any.whl (25 kB)
# Downloading jsonschema-4.20.0-py3-none-any.whl (84 kB)
#    ---------------------------------------- 0.0/84.7 kB ? eta -:--:--
#    ---------------------------------------- 84.7/84.7 kB 2.3 MB/s eta 0:00:00
# Using cached pystac-1.9.0-py3-none-any.whl (181 kB)
# Downloading jsonschema_specifications-2023.11.1-py3-none-any.whl (17 kB)
# Downloading referencing-0.31.0-py3-none-any.whl (25 kB)
# Downloading rpds_py-0.13.1-cp39-none-win_amd64.whl (189 kB)
#    ---------------------------------------- 0.0/189.1 kB ? eta -:--:--
#    ------------------- -------------------- 92.2/189.1 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 189.1/189.1 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: pmtiles, colour, traittypes, scooby, rpds-py, python-box, pyshp, geojson, duckdb, attrs, whitebox, referencing, pystac, branca, jsonschema-specifications, gdown, folium, flask-cors, jsonschema, pystac-client, ipytree, ipyleaflet, ipyfilechooser, ipyevents, bqplot, whiteboxgui, leafmap
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.1.0
#     Uninstalling attrs-22.1.0:
#       Successfully uninstalled attrs-22.1.0
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.17.3
#     Uninstalling jsonschema-4.17.3:
#       Successfully uninstalled jsonschema-4.17.3
# Successfully installed attrs-23.1.0 bqplot-0.12.42 branca-0.7.0 colour-0.1.5 duckdb-0.9.2 flask-cors-4.0.0 folium-0.15.0 gdown-4.7.1 geojson-3.1.0 ipyevents-2.0.2 ipyfilechooser-0.6.0 ipyleaflet-0.18.0 ipytree-0.2.2 jsonschema-4.20.0 jsonschema-specifications-2023.11.1 leafmap-0.29.3 pmtiles-3.2.0 pyshp-2.3.1 pystac-1.9.0 pystac-client-0.7.5 python-box-7.1.1 referencing-0.31.0 rpds-py-0.13.1 scooby-0.9.2 traittypes-0.2.1 whitebox-2.3.1 whiteboxgui-2.3.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import libraries
#
# Currently, ipyleaflet does not support PMTiles. We will use folium mapping backend with leafmap.

# %%
import leafmap.foliumap as leafmap

# %%
# %pip install pmtiles
# Out:
# Requirement already satisfied: pmtiles in c:\users\vance\anaconda3\envs\geo\envs\py39\lib\site-packages (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## PMTiles Viewer
#
# The [PMTiles Viewer](https://protomaps.github.io/PMTiles) can be used to view the contents of a PMTiles archive using a web browser. This is a useful tool for visualizing the contents of a PMTiles archive without writing any code. However, you can't use it with Jupyter notebook.

# %% [markdown]
# ## Remote PMTiles
#
# PMTiles can be hosted on a cloud storage platform or locally. In this section, we will visualize a PMTiles hosted on a remote server.
#
# ### Protomaps sample data
#
# The [PMTiles Viewer](https://protomaps.github.io/PMTiles) provides a list of sample PMTiles archives. We will use the [ODbL_firenze.pmtiles](<https://protomaps.github.io/PMTiles/protomaps(vector)ODbL_firenze.pmtiles>). First, let's inspect the metadata of the PMTiles archive.

# %%
url = "https://protomaps.github.io/PMTiles/protomaps(vector)ODbL_firenze.pmtiles"
metadata = leafmap.pmtiles_metadata(url)
metadata
# Out:
# {'attribution': '<a href="https://protomaps.com" target="_blank">Protomaps</a> © <a href="https://www.openstreetmap.org" target="_blank"> OpenStreetMap</a>',
#  'name': 'protomaps 2023-01-18T07:49:39Z',
#  'type': 'baselayer',
#  'vector_layers': [{'fields': {}, 'id': 'earth'},
#   {'fields': {'boundary': 'string',
#     'landuse': 'string',
#     'leisure': 'string',
#     'name': 'string',
#     'natural': 'string'},
#    'id': 'natural'},
#   {'fields': {'aeroway': 'string',
#     'amenity': 'string',
#     'area:aeroway': 'string',
#     'highway': 'string',
#     'landuse': 'string',
#     'leisure': 'string',
#     'man_made': 'string',
#     'name': 'string',
#     'place': 'string',
#     'pmap:kind': 'string',
#     'railway': 'string',
#     'sport': 'string'},
#    'id': 'land'},
#   {'fields': {'landuse': 'string',
#     'leisure': 'string',
#     'name': 'string',
#     'natural': 'string',
#     'water': 'string',
#     'waterway': 'string'},
#    'id': 'water'},
#   {'fields': {'natural': 'string', 'waterway': 'string'},
#    'id': 'physical_line'},
#   {'fields': {'building:part': 'string',
#     'height': 'number',
#     'layer': 'string',
#     'name': 'string'},
#    'id': 'buildings'},
#   {'fields': {'ele': 'number',
#     'name': 'string',
#     'natural': 'string',
#     'place': 'string'},
#    'id': 'physical_point'},
#   {'fields': {'capital': 'string',
#     'country_code_iso3166_1_alpha_2': 'string',
#     'name': 'string',
#     'place': 'string',
#     'pmap:kind': 'string',
#     'pmap:rank': 'string',
#     'population': 'string'},
#    'id': 'places'},
#   {'fields': {'bridge': 'string',
#     'highway': 'string',
#     'layer': 'string',
#     'oneway': 'string',
#     'pmap:kind': 'string',
#     'ref': 'string',
#     'tunnel': 'string'},
#    'id': 'roads'},
#   {'fields': {'aerialway': 'string',
#     'aeroway': 'string',
#     'highspeed': 'string',
#     'layer': 'string',
#     'name': 'string',
#     'network': 'string',
#     'pmap:kind': 'string',
#     'railway': 'string',
#     'ref': 'string',
#     'route': 'string',
#     'service': 'string'},
#    'id': 'transit'},
#   {'fields': {'amenity': 'string',
#     'cuisine': 'string',
#     'name': 'string',
#     'railway': 'string',
#     'religion': 'string',
#     'shop': 'string',
#     'tourism': 'string'},
#    'id': 'pois'},
#   {'fields': {'pmap:min_admin_level': 'number'}, 'id': 'boundaries'},
#   {'fields': {}, 'id': 'mask'}],
#  'layer_names': ['earth',
#   'natural',
#   'land',
#   'water',
#   'physical_line',
#   'buildings',
#   'physical_point',
#   'places',
#   'roads',
#   'transit',
#   'pois',
#   'boundaries',
#   'mask'],
#  'center': [43.779779, 11.2414827],
#  'bounds': [11.154026, 43.7270125, 11.3289395, 43.8325455]}

# %% [markdown]
# Get the list of layers.

# %%
print(f"layer names: {metadata['layer_names']}")
# Out:
# layer names: ['earth', 'natural', 'land', 'water', 'physical_line', 'buildings', 'physical_point', 'places', 'roads', 'transit', 'pois', 'boundaries', 'mask']

# %% [markdown]
# Get the layer center.

# %%
print(f"center: {metadata['center']}")
# Out:
# center: [43.779779, 11.2414827]

# %% [markdown]
# Get the layer bounds.

# %%
print(f"bounds: {metadata['bounds']}")
# Out:
# bounds: [11.154026, 43.7270125, 11.3289395, 43.8325455]

# %% [markdown]
# Visualize the layer with the default style.

# %%
# cmap color ramps are at leafmap.org notebook 23 colormaps
# set to classes by adding ...cmap='Set3', n_class=12) see below with coolwarm
style = leafmap.pmtiles_style(url, cmap='Set3')
style
# Out:
# {'version': 8,
#  'sources': {'source': {'type': 'vector',
#    'url': 'pmtiles://https://protomaps.github.io/PMTiles/protomaps(vector)ODbL_firenze.pmtiles',
#    'attribution': 'PMTiles'}},
#  'layers': [{'id': 'earth_point',
#    'source': 'source',
#    'source-layer': 'earth',
#    'type': 'circle',
#    'paint': {'circle-color': '#8dd3c7', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'earth_stroke',
#    'source': 'source',
#    'source-layer': 'earth',
#    'type': 'line',
#    'paint': {'line-color': '#8dd3c7', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'earth_fill',
#    'source': 'source',
#    'source-layer': 'earth',
#    'type': 'fill',
#    'paint': {'fill-color': '#8dd3c7', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'natural_point',
#    'source': 'source',
#    'source-layer': 'natural',
#    'type': 'circle',
#    'paint': {'circle-color': '#ffffb3', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'natural_stroke',
#    'source': 'source',
#    'source-layer': 'natural',
#    'type': 'line',
#    'paint': {'line-color': '#ffffb3', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'natural_fill',
#    'source': 'source',
#    'source-layer': 'natural',
#    'type': 'fill',
#    'paint': {'fill-color': '#ffffb3', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'land_point',
#    'source': 'source',
#    'source-layer': 'land',
#    'type': 'circle',
#    'paint': {'circle-color': '#bebada', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'land_stroke',
#    'source': 'source',
#    'source-layer': 'land',
#    'type': 'line',
#    'paint': {'line-color': '#bebada', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'land_fill',
#    'source': 'source',
#    'source-layer': 'land',
#    'type': 'fill',
#    'paint': {'fill-color': '#bebada', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'water_point',
#    'source': 'source',
#    'source-layer': 'water',
#    'type': 'circle',
#    'paint': {'circle-color': '#fb8072', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'water_stroke',
#    'source': 'source',
#    'source-layer': 'water',
#    'type': 'line',
#    'paint': {'line-color': '#fb8072', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'water_fill',
#    'source': 'source',
#    'source-layer': 'water',
#    'type': 'fill',
#    'paint': {'fill-color': '#fb8072', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'physical_line_point',
#    'source': 'source',
#    'source-layer': 'physical_line',
#    'type': 'circle',
#    'paint': {'circle-color': '#80b1d3', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'physical_line_stroke',
#    'source': 'source',
#    'source-layer': 'physical_line',
#    'type': 'line',
#    'paint': {'line-color': '#80b1d3', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'physical_line_fill',
#    'source': 'source',
#    'source-layer': 'physical_line',
#    'type': 'fill',
#    'paint': {'fill-color': '#80b1d3', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'buildings_point',
#    'source': 'source',
#    'source-layer': 'buildings',
#    'type': 'circle',
#    'paint': {'circle-color': '#fdb462', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'buildings_stroke',
#    'source': 'source',
#    'source-layer': 'buildings',
#    'type': 'line',
#    'paint': {'line-color': '#fdb462', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'buildings_fill',
#    'source': 'source',
#    'source-layer': 'buildings',
#    'type': 'fill',
#    'paint': {'fill-color': '#fdb462', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'physical_point_point',
#    'source': 'source',
#    'source-layer': 'physical_point',
#    'type': 'circle',
#    'paint': {'circle-color': '#b3de69', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'physical_point_stroke',
#    'source': 'source',
#    'source-layer': 'physical_point',
#    'type': 'line',
#    'paint': {'line-color': '#b3de69', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'physical_point_fill',
#    'source': 'source',
#    'source-layer': 'physical_point',
#    'type': 'fill',
#    'paint': {'fill-color': '#b3de69', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'places_point',
#    'source': 'source',
#    'source-layer': 'places',
#    'type': 'circle',
#    'paint': {'circle-color': '#fccde5', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'places_stroke',
#    'source': 'source',
#    'source-layer': 'places',
#    'type': 'line',
#    'paint': {'line-color': '#fccde5', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'places_fill',
#    'source': 'source',
#    'source-layer': 'places',
#    'type': 'fill',
#    'paint': {'fill-color': '#fccde5', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'roads_point',
#    'source': 'source',
#    'source-layer': 'roads',
#    'type': 'circle',
#    'paint': {'circle-color': '#d9d9d9', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'roads_stroke',
#    'source': 'source',
#    'source-layer': 'roads',
#    'type': 'line',
#    'paint': {'line-color': '#d9d9d9', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'roads_fill',
#    'source': 'source',
#    'source-layer': 'roads',
#    'type': 'fill',
#    'paint': {'fill-color': '#d9d9d9', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'transit_point',
#    'source': 'source',
#    'source-layer': 'transit',
#    'type': 'circle',
#    'paint': {'circle-color': '#bc80bd', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'transit_stroke',
#    'source': 'source',
#    'source-layer': 'transit',
#    'type': 'line',
#    'paint': {'line-color': '#bc80bd', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'transit_fill',
#    'source': 'source',
#    'source-layer': 'transit',
#    'type': 'fill',
#    'paint': {'fill-color': '#bc80bd', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'pois_point',
#    'source': 'source',
#    'source-layer': 'pois',
#    'type': 'circle',
#    'paint': {'circle-color': '#ccebc5', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'pois_stroke',
#    'source': 'source',
#    'source-layer': 'pois',
#    'type': 'line',
#    'paint': {'line-color': '#ccebc5', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'pois_fill',
#    'source': 'source',
#    'source-layer': 'pois',
#    'type': 'fill',
#    'paint': {'fill-color': '#ccebc5', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'boundaries_point',
#    'source': 'source',
#    'source-layer': 'boundaries',
#    'type': 'circle',
#    'paint': {'circle-color': '#ffed6f', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'boundaries_stroke',
#    'source': 'source',
#    'source-layer': 'boundaries',
#    'type': 'line',
#    'paint': {'line-color': '#ffed6f', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'boundaries_fill',
#    'source': 'source',
#    'source-layer': 'boundaries',
#    'type': 'fill',
#    'paint': {'fill-color': '#ffed6f', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']},
#   {'id': 'mask_point',
#    'source': 'source',
#    'source-layer': 'mask',
#    'type': 'circle',
#    'paint': {'circle-color': '#8dd3c7', 'circle-radius': 5},
#    'filter': ['==', ['geometry-type'], 'Point']},
#   {'id': 'mask_stroke',
#    'source': 'source',
#    'source-layer': 'mask',
#    'type': 'line',
#    'paint': {'line-color': '#8dd3c7', 'line-width': 1},
#    'filter': ['==', ['geometry-type'], 'LineString']},
#   {'id': 'mask_fill',
#    'source': 'source',
#    'source-layer': 'mask',
#    'type': 'fill',
#    'paint': {'fill-color': '#8dd3c7', 'fill-opacity': 0.5},
#    'filter': ['==', ['geometry-type'], 'Polygon']}]}

# %%
m = leafmap.Map()
m.add_basemap('CartoDB.DarkMatter')
m.add_pmtiles(
    url,
    name='PMTiles',
    style=style,
    zoom_to_layer=True,
    tooltip=False,
)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d424c584d1d6b340977e9307b24f83b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/pmtiles@2.7.1/dist/index.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/maplibre-gl@2.2.1/dist/maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@maplibre/maplibre-gl-leaflet@0.0.19/leaflet-maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/maplibre-gl@2.4.0/dist/maplibre-gl.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d424c584d1d6b340977e9307b24f83b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9d424c584d1d6b340977e9307b24f83b = L.map(
#                 &quot;map_9d424c584d1d6b340977e9307b24f83b&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_9d424c584d1d6b340977e9307b24f83b);
#
#
#
#
#
#             var tile_layer_ae5067ae72269cb9feef23965e19d211 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_ae5067ae72269cb9feef23965e19d211.addTo(map_9d424c584d1d6b340977e9307b24f83b);
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_9d424c584d1d6b340977e9307b24f83b);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_1f835b51b6a7cd3336c699090a713cb8 = new L.featureGroup().addTo(
#                 map_9d424c584d1d6b340977e9307b24f83b
#             );
#             options.edit.featureGroup = drawnItems_draw_control_1f835b51b6a7cd3336c699090a713cb8;
#             var draw_control_1f835b51b6a7cd3336c699090a713cb8 = new L.Control.Draw(
#                 options
#             ).addTo( map_9d424c584d1d6b340977e9307b24f83b );
#             map_9d424c584d1d6b340977e9307b24f83b.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_1f835b51b6a7cd3336c699090a713cb8.addLayer(layer);
#              });
#             map_9d424c584d1d6b340977e9307b24f83b.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_1f835b51b6a7cd3336c699090a713cb8.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_7f96ccbb2c277a213d49be9a4079ef3b = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_9d424c584d1d6b340977e9307b24f83b.addControl(measure_control_7f96ccbb2c277a213d49be9a4079ef3b);
#
#             // Workaround for using this plugin with Leaflet&gt;=1.8.0
#             // https://github.com/ljagis/leaflet-measure/issues/171
#             L.Control.Measure.include({
#                 _setCaptureMarkerIcon: function () {
#                     // disable autopan
#                     this._captureMarker.options.autoPanOnFocus = false;
#                     // default function
#                     this._captureMarker.setIcon(

# %%
style = leafmap.pmtiles_style(url, cmap='coolwarm', n_class=12)
style
m = leafmap.Map()
m.add_basemap('CartoDB.DarkMatter')
m.add_pmtiles(
    url,
    name='PMTiles',
    style=style,
    zoom_to_layer=True,
    tooltip=False,
)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5db0cd38340642df0cbe49989ab62f28 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/pmtiles@2.7.1/dist/index.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/maplibre-gl@2.2.1/dist/maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@maplibre/maplibre-gl-leaflet@0.0.19/leaflet-maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/maplibre-gl@2.4.0/dist/maplibre-gl.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5db0cd38340642df0cbe49989ab62f28&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5db0cd38340642df0cbe49989ab62f28 = L.map(
#                 &quot;map_5db0cd38340642df0cbe49989ab62f28&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_5db0cd38340642df0cbe49989ab62f28);
#
#
#
#
#
#             var tile_layer_6b82df50cb546f937a521b2c5d646ecc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_6b82df50cb546f937a521b2c5d646ecc.addTo(map_5db0cd38340642df0cbe49989ab62f28);
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_5db0cd38340642df0cbe49989ab62f28);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_56bf273af6375e11b017f40c1a508c98 = new L.featureGroup().addTo(
#                 map_5db0cd38340642df0cbe49989ab62f28
#             );
#             options.edit.featureGroup = drawnItems_draw_control_56bf273af6375e11b017f40c1a508c98;
#             var draw_control_56bf273af6375e11b017f40c1a508c98 = new L.Control.Draw(
#                 options
#             ).addTo( map_5db0cd38340642df0cbe49989ab62f28 );
#             map_5db0cd38340642df0cbe49989ab62f28.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_56bf273af6375e11b017f40c1a508c98.addLayer(layer);
#              });
#             map_5db0cd38340642df0cbe49989ab62f28.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_56bf273af6375e11b017f40c1a508c98.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_9f22c6a331d27f0b7abd170cd3529a24 = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_5db0cd38340642df0cbe49989ab62f28.addControl(measure_control_9f22c6a331d27f0b7abd170cd3529a24);
#
#             // Workaround for using this plugin with Leaflet&gt;=1.8.0
#             // https://github.com/ljagis/leaflet-measure/issues/171
#             L.Control.Measure.include({
#                 _setCaptureMarkerIcon: function () {
#                     // disable autopan
#                     this._captureMarker.options.autoPanOnFocus = false;
#                     // default function
#                     this._captureMarker.setIcon(

# %% [markdown]
# Visualize the layer with a custom style.

# %%
m = leafmap.Map()

style = {
    "version": 8,
    "sources": {
        "example_source": {
            "type": "vector",
            "url": "pmtiles://" + url,
            "attribution": 'PMTiles',
        }
    },
    "layers": [
        {
            "id": "buildings",
            "source": "example_source",
            "source-layer": "landuse",
            "type": "fill",
            "paint": {"fill-color": "steelblue"}, #change fill color here and add 'fill-opacity': 0.5 to make it transparent
        },
        {
            "id": "roads",
            "source": "example_source",
            "source-layer": "roads",
            "type": "line",
            "paint": {"line-color": "black"},
        },
    ],
}
# change tooltip=False to turn off windows when hovering over map
m.add_pmtiles(
    url, name='PMTiles', style=style, zoom_to_layer=True, tooltip=True
)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bceed2642f72e5345d0fc240d35807ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/pmtiles@2.7.1/dist/index.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/maplibre-gl@2.2.1/dist/maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@maplibre/maplibre-gl-leaflet@0.0.19/leaflet-maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/maplibre-gl@2.4.0/dist/maplibre-gl.css&quot;/&gt;
#
#             &lt;style&gt;
#             .maplibregl-popup {
#                 font: 12px/20px &#x27;Helvetica Neue&#x27;, Arial, Helvetica, sans-serif;
#                 z-index: 651;
#             }
#             .feature-row{
#                 margin-bottom: 0.5em;
#                 &amp;:not(:last-of-type) {
#                     border-bottom: 1px solid black;
#                 }
#             }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bceed2642f72e5345d0fc240d35807ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bceed2642f72e5345d0fc240d35807ec = L.map(
#                 &quot;map_bceed2642f72e5345d0fc240d35807ec&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_bceed2642f72e5345d0fc240d35807ec);
#
#
#
#
#
#             var tile_layer_ca592bad6e6c7966faeae99364d31d28 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_ca592bad6e6c7966faeae99364d31d28.addTo(map_bceed2642f72e5345d0fc240d35807ec);
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_bceed2642f72e5345d0fc240d35807ec);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_047f5186d3c7d274060c3429f795f6c6 = new L.featureGroup().addTo(
#                 map_bceed2642f72e5345d0fc240d35807ec
#             );
#             options.edit.featureGroup = drawnItems_draw_control_047f5186d3c7d274060c3429f795f6c6;
#             var draw_control_047f5186d3c7d274060c3429f795f6c6 = new L.Control.Draw(
#                 options
#             ).addTo( map_bceed2642f72e5345d0fc240d35807ec );
#             map_bceed2642f72e5345d0fc240d35807ec.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_047f5186d3c7d274060c3429f795f6c6.addLayer(layer);
#              });
#             map_bceed2642f72e5345d0fc240d35807ec.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_047f5186d3c7d274060c3429f795f6c6.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_39c8a465724b4e1a2197a8bd4ee9e04a = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_bceed2642f72e5345d0fc240d35807ec.addControl(measure_control_39c8a465724b4e1a2197a8bd4ee9e04a);

# %% [markdown]
# ### Overture data

# %% [markdown]
# You can also visualize [Overture data](https://overturemaps.org/). First, let's inspect the metadata of the PMTiles archive.

# %%
url = "https://storage.googleapis.com/ahp-research/overture/pmtiles/overture.pmtiles"
metadata = leafmap.pmtiles_metadata(url)
print(f"layer names: {metadata['layer_names']}")
print(f"bounds: {metadata['bounds']}")
# Out:
# layer names: ['admins', 'buildings', 'places', 'roads']
# bounds: [3.295898, 50.746884, 7.245483, 53.5762]

# %% [markdown]
# Visualize the layer with the default style.

# %%
m = leafmap.Map(height='800px')
m.add_basemap('CartoDB.DarkMatter')
m.add_pmtiles(url, name='PMTiles', tooltip=False)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ff1cc5850fed3a06a01026bc6875f38 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/pmtiles@2.7.1/dist/index.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/maplibre-gl@2.2.1/dist/maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@maplibre/maplibre-gl-leaflet@0.0.19/leaflet-maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/maplibre-gl@2.4.0/dist/maplibre-gl.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ff1cc5850fed3a06a01026bc6875f38&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ff1cc5850fed3a06a01026bc6875f38 = L.map(
#                 &quot;map_2ff1cc5850fed3a06a01026bc6875f38&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_2ff1cc5850fed3a06a01026bc6875f38);
#
#
#
#
#
#             var tile_layer_17ae148efa95f5ba3d286bad0b3011dc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_17ae148efa95f5ba3d286bad0b3011dc.addTo(map_2ff1cc5850fed3a06a01026bc6875f38);
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_2ff1cc5850fed3a06a01026bc6875f38);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_4e242645462be13e9619b2650ad36d84 = new L.featureGroup().addTo(
#                 map_2ff1cc5850fed3a06a01026bc6875f38
#             );
#             options.edit.featureGroup = drawnItems_draw_control_4e242645462be13e9619b2650ad36d84;
#             var draw_control_4e242645462be13e9619b2650ad36d84 = new L.Control.Draw(
#                 options
#             ).addTo( map_2ff1cc5850fed3a06a01026bc6875f38 );
#             map_2ff1cc5850fed3a06a01026bc6875f38.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_4e242645462be13e9619b2650ad36d84.addLayer(layer);
#              });
#             map_2ff1cc5850fed3a06a01026bc6875f38.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_4e242645462be13e9619b2650ad36d84.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_14d589e3795cf602cedb1d6ee2bb34ac = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_2ff1cc5850fed3a06a01026bc6875f38.addControl(measure_control_14d589e3795cf602cedb1d6ee2bb34ac);
#
#             // Workaround for using this plugin with Leaflet&gt;=1.8.0
#             // https://github.com/ljagis/leaflet-measure/issues/171
#             L.Control.Measure.include({
#                 _setCaptureMarkerIcon: function () {
#                     // disable autopan
#                     this._captureMarker.options.autoPanOnFocus = false;
#                     // default function
#                     this._captureMarker.setIcon(

# %% [markdown]
# Visualize the layer with a custom style.

# %%
m = leafmap.Map(height='800px')
m.add_basemap('CartoDB.DarkMatter')

style = {
    "version": 8,
    "sources": {
        "example_source": {
            "type": "vector",
            "url": "pmtiles://" + url,
            "attribution": 'PMTiles',
        }
    },
    "layers": [
        {
            "id": "admins",
            "source": "example_source",
            "source-layer": "admins",
            "type": "fill",
            "paint": {"fill-color": "#BDD3C7", "fill-opacity": 0.1},
        },
        {
            "id": "buildings",
            "source": "example_source",
            "source-layer": "buildings",
            "type": "fill",
            "paint": {"fill-color": "#FFFFB3", "fill-opacity": 0.5},
        },
        {
            "id": "places",
            "source": "example_source",
            "source-layer": "places", #most important line for the layer, needs to be same as layer name in metadata
            "type": "fill",
            "paint": {"fill-color": "#BEBADA", "fill-opacity": 0.5},
        },
        {
            "id": "roads",
            "source": "example_source",
            "source-layer": "roads",
            "type": "line",
            "paint": {"line-color": "#FB8072"},
        },
    ],
}

m.add_pmtiles(url, name='PMTiles', style=style, tooltip=False)

legend_dict = {
    'admins': 'BDD3C7',
    'buildings': 'FFFFB3',
    'places': 'BEBADA',
    'roads': 'FB8072',
}

m.add_legend(legend_dict=legend_dict)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_34d85754cf866f1dc5f5fe133d3fb73a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/pmtiles@2.7.1/dist/index.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/maplibre-gl@2.2.1/dist/maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@maplibre/maplibre-gl-leaflet@0.0.19/leaflet-maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/maplibre-gl@2.4.0/dist/maplibre-gl.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_34d85754cf866f1dc5f5fe133d3fb73a&quot; &gt;&lt;/div&gt;
#
#
# &lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1&quot;&gt;
#   &lt;title&gt;jQuery UI Draggable - Default functionality&lt;/title&gt;
#   &lt;link rel=&quot;stylesheet&quot; href=&quot;//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css&quot;&gt;
#
#   &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.js&quot;&gt;&lt;/script&gt;
#   &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#
#   &lt;script&gt;
#   $( function() {
#     $( &quot;#maplegend&quot; ).draggable({
#                     start: function (event, ui) {
#                         $(this).css({
#                             right: &quot;auto&quot;,
#                             top: &quot;auto&quot;,
#                             bottom: &quot;auto&quot;
#                         });
#                     }
#                 });
# });
#
#   &lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div id=&#x27;maplegend&#x27; class=&#x27;maplegend&#x27;
#     style=&#x27;position: absolute; z-index:9999; border:2px solid grey; background-color:rgba(255, 255, 255, 0.8);
#      border-radius:6px; padding: 10px; font-size:14px; right: 20px; bottom: 20px;&#x27;&gt;
#
# &lt;div class=&#x27;legend-title&#x27;&gt;Legend&lt;/div&gt;
# &lt;div class=&#x27;legend-scale&#x27;&gt;
#   &lt;ul class=&#x27;legend-labels&#x27;&gt;
#     &lt;li&gt;&lt;span style=&#x27;background:#bdd3c7;opacity:1.0;&#x27;&gt;&lt;/span&gt;admins&lt;/li&gt;
#     &lt;li&gt;&lt;span style=&#x27;background:#ffffb3;opacity:1.0;&#x27;&gt;&lt;/span&gt;buildings&lt;/li&gt;
#     &lt;li&gt;&lt;span style=&#x27;background:#bebada;opacity:1.0;&#x27;&gt;&lt;/span&gt;places&lt;/li&gt;
#     &lt;li&gt;&lt;span style=&#x27;background:#fb8072;opacity:1.0;&#x27;&gt;&lt;/span&gt;roads&lt;/li&gt;
#   &lt;/ul&gt;
# &lt;/div&gt;
# &lt;/div&gt;
#
# &lt;/body&gt;
# &lt;/html&gt;
#
# &lt;style type=&#x27;text/css&#x27;&gt;
#   .maplegend .legend-title {
#     text-align: left;
#     margin-bottom: 5px;
#     font-weight: bold;
#     font-size: 90%;
#     }
#   .maplegend .legend-scale ul {
#     margin: 0;
#     margin-bottom: 5px;
#     padding: 0;
#     float: left;
#     list-style: none;
#     }
#   .maplegend .legend-scale ul li {
#     font-size: 80%;
#     list-style: none;
#     margin-left: 0;
#     line-height: 18px;
#     margin-bottom: 2px;
#     }
#   .maplegend ul.legend-labels li span {
#     display: block;
#     float: left;
#     height: 16px;
#     width: 30px;
#     margin-right: 5px;
#     margin-left: 0;
#     border: 1px solid #999;
#     }
#   .maplegend .legend-source {
#     font-size: 80%;
#     color: #777;
#     clear: both;
#     }
#   .maplegend a {
#     color: #777;
#     }
# &lt;/style&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_34d85754cf866f1dc5f5fe133d3fb73a = L.map(
#                 &quot;map_34d85754cf866f1dc5f5fe133d3fb73a&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_34d85754cf866f1dc5f5fe133d3fb73a);
#
#
#
#
#
#             var tile_layer_0764635dc175f79653f7cf99cd0463ff = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc

# %% [markdown]
# ### Source Cooperative
#
# [Source Cooperative](https://source.coop) hosts a variety of open geospatial data in PMTiles format. In this example, we will visualize the [Google-Microsoft Open Buildings](https://beta.source.coop/repositories/vida/google-microsoft-open-buildings/description) dataset (193.9 GB). First, let's inspect the metadata of the PMTiles archive.

# %%
url = 'https://data.source.coop/vida/google-microsoft-open-buildings/pmtiles/go_ms_building_footprints.pmtiles'
metadata = leafmap.pmtiles_metadata(url)
print(f"layer names: {metadata['layer_names']}")
print(f"bounds: {metadata['bounds']}")
# Out:
# layer names: ['building_footprints']
# bounds: [-160.221701, -55.9756776, 166.709685, 74.7731168]

# %%
m = leafmap.Map(center=[20, 0], zoom=2, height='800px')
m.add_basemap('CartoDB.DarkMatter')
m.add_basemap('Esri.WorldImagery', show=False)

style = {
    "version": 8,
    "sources": {
        "example_source": {
            "type": "vector",
            "url": "pmtiles://" + url,
            "attribution": 'PMTiles',
        }
    },
    "layers": [
        {
            "id": "buildings",
            "source": "example_source",
            "source-layer": "building_footprints",
            "type": "fill",
            "paint": {"fill-color": "#3388ff", "fill-opacity": 0.5},
        },
    ],
}

m.add_pmtiles(
    url, name='Buildings', style=style, tooltip=False
)

html = "Source: <a href='https://beta.source.coop/repositories/vida/google-microsoft-open-buildings/description' target='_blank'>source.coop</a>"
m.add_html(html, position='bottomright')

m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77fbab46fe8172085cbaf3b82bc6b238 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/pmtiles@2.7.1/dist/index.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/maplibre-gl@2.2.1/dist/maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@maplibre/maplibre-gl-leaflet@0.0.19/leaflet-maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/maplibre-gl@2.4.0/dist/maplibre-gl.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77fbab46fe8172085cbaf3b82bc6b238&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77fbab46fe8172085cbaf3b82bc6b238 = L.map(
#                 &quot;map_77fbab46fe8172085cbaf3b82bc6b238&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_77fbab46fe8172085cbaf3b82bc6b238);
#
#
#
#
#
#             var tile_layer_36328650165609a4a39670748f6906c6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_36328650165609a4a39670748f6906c6.addTo(map_77fbab46fe8172085cbaf3b82bc6b238);
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_77fbab46fe8172085cbaf3b82bc6b238);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_44a06b706b57e38bcbdda973c4a47a32 = new L.featureGroup().addTo(
#                 map_77fbab46fe8172085cbaf3b82bc6b238
#             );
#             options.edit.featureGroup = drawnItems_draw_control_44a06b706b57e38bcbdda973c4a47a32;
#             var draw_control_44a06b706b57e38bcbdda973c4a47a32 = new L.Control.Draw(
#                 options
#             ).addTo( map_77fbab46fe8172085cbaf3b82bc6b238 );
#             map_77fbab46fe8172085cbaf3b82bc6b238.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_44a06b706b57e38bcbdda973c4a47a32.addLayer(layer);
#              });
#             map_77fbab46fe8172085cbaf3b82bc6b238.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_44a06b706b57e38bcbdda973c4a47a32.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_93fa97f059a31ccf6429190b7d8d38b1 = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_77fbab46fe8172085cbaf3b82bc6b238.addControl(measure_control_93fa97f059a31ccf6429190b7d8d38b1);
#
#             // Workaround for using this plugin with Leaflet&gt;=1.8.0
#             // https://github.com/ljagis/leaflet-measure/issues/171
#             L.Control.Measure.include({
#                 _setCaptureMarkerIcon: function () {
#                     // disable autopan
#                     this._captureMarker.options.autoPanOnFocus = false;
#                     // default function
#                     this._captureMarker.setIcon(

# %%
# save to an html
m.save('buildings.html')

# %% [markdown]
# ## Local PMTiles
#
# tippecanoe is required to convert vector data to pmtiles. Install it with `mamba install -c conda-forge tippecanoe`.
#
# Download [building footprints](https://github.com/opengeos/open-data/blob/main/datasets/libya/Derna_buildings.geojson) of Derna, Libya.

# %%
# function doesn't work in windows, only mac linux
url = 'https://raw.githubusercontent.com/opengeos/open-data/main/datasets/libya/Derna_buildings.geojson'
leafmap.download_file(url, 'buildings.geojson')

# %% [markdown]
# Convert vector to PMTiles.

# %%
pmtiles = 'buildings.pmtiles'
leafmap.geojson_to_pmtiles(
    'buildings.geojson',
    pmtiles,
    layer_name='buildings',
    overwrite=True,
    quiet=True
)

# %% [markdown]
# Start a HTTP Sever

# %%
leafmap.start_server(port=8000)

# %%
url = f'http://127.0.0.1:8000/{pmtiles}'
# leafmap.pmtiles_metadata(url)

# %% [markdown]
# Diplay the PMTiles on the map.

# %%
m = leafmap.Map()
m.add_basemap('CartoDB.DarkMatter')
m.add_basemap('SATELLITE')

style = {
    "version": 8,
    "sources": {
        "example_source": {
            "type": "vector",
            "url": "pmtiles://" + url,
            "attribution": 'PMTiles',
        }
    },
    "layers": [
        {
            "id": "buildings",
            "source": "example_source",
            "source-layer": "buildings",
            "type": "fill",
            "paint": {"fill-color": "#3388ff", "fill-opacity": 0.5},
        },
    ],
}

# style = leafmap.pmtiles_style(url)  # Use default style

m.add_pmtiles(url, name='Buildings', show=True, zoom_to_layer=True, style=style)
m

# %%
# Add overture open buildings from source coop
url = 'https://data.source.coop/cholmes/overture/overture-buildings.pmtiles'
metadata = leafmap.pmtiles_metadata(url)
metadata['layer_names']
# Out:
# ['buildings']

# %%
m = leafmap.Map()
m.add_basemap('CartoDB.DarkMatter')
m.add_pmtiles(url, tooltip=False)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_854d1c1e761bc0c9f021471f564e7eae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/pmtiles@2.7.1/dist/index.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/maplibre-gl@2.2.1/dist/maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@maplibre/maplibre-gl-leaflet@0.0.19/leaflet-maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/maplibre-gl@2.4.0/dist/maplibre-gl.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_854d1c1e761bc0c9f021471f564e7eae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_854d1c1e761bc0c9f021471f564e7eae = L.map(
#                 &quot;map_854d1c1e761bc0c9f021471f564e7eae&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_854d1c1e761bc0c9f021471f564e7eae);
#
#
#
#
#
#             var tile_layer_8dbe3f1a5b572a053068911832e364a9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_8dbe3f1a5b572a053068911832e364a9.addTo(map_854d1c1e761bc0c9f021471f564e7eae);
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_854d1c1e761bc0c9f021471f564e7eae);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_04e30db9917d5b03bb7c5fcf97e27519 = new L.featureGroup().addTo(
#                 map_854d1c1e761bc0c9f021471f564e7eae
#             );
#             options.edit.featureGroup = drawnItems_draw_control_04e30db9917d5b03bb7c5fcf97e27519;
#             var draw_control_04e30db9917d5b03bb7c5fcf97e27519 = new L.Control.Draw(
#                 options
#             ).addTo( map_854d1c1e761bc0c9f021471f564e7eae );
#             map_854d1c1e761bc0c9f021471f564e7eae.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_04e30db9917d5b03bb7c5fcf97e27519.addLayer(layer);
#              });
#             map_854d1c1e761bc0c9f021471f564e7eae.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_04e30db9917d5b03bb7c5fcf97e27519.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_776719d6216f50cf40a27e767b742fab = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_854d1c1e761bc0c9f021471f564e7eae.addControl(measure_control_776719d6216f50cf40a27e767b742fab);
#
#             // Workaround for using this plugin with Leaflet&gt;=1.8.0
#             // https://github.com/ljagis/leaflet-measure/issues/171
#             L.Control.Measure.include({
#                 _setCaptureMarkerIcon: function () {
#                     // disable autopan
#                     this._captureMarker.options.autoPanOnFocus = false;
#                     // default function
#                     this._captureMarker.setIcon(
